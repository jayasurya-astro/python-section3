# %%
##for loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#for loop
for i in range(1,10,5):
    print(i)
# Out:
# 1
# 6

# %%
## strings
str = 'jaya surya'
for i in str:
    print(i)
# Out:
# j
# a
# y
# a
#
# s
# u
# r
# y
# a

# %%
count=0
while count<5:
    print(count)
    count = count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#for loop
for i in range(10,1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
##whileloop
